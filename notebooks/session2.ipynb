# %% [markdown]
# # Session 2
# Basic Python in Jupyter Notebook

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 5
b = 3.2
c = True
d = None

print(a, b, c, d)
# Out:
# 5 3.2 True None

# %%
x = 10
y = 3

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x ** y)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1000

# %%
planet = "Mars"
gravity = 3.73

print(planet)
print(gravity)
# Out:
# Mars
# 3.73

# %%
a = 10
b = 3.14
c = "hello"

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
name = "Khuzzaim"

print(name)
print(name.upper())
print(name.lower())
# Out:
# Khuzzaim
# KHUZZAIM
# khuzzaim

# %%
age = 25

# %%
name = "Khuzzaim"

# %%
print(name)
# Out:
# Khuzzaim

# %%
print("Hello")
# Out:
# Hello

# %%
print(f"{name} is {age} years old")
# Out:
# Khuzzaim is 25 years old

# %%
a = 5
b = 3

print(a + b)
# Out:
# 8

# %%
alist = [10, 20, 30]

# %%
alist[1]
# Out:
# 20

# %%
alist.append(10)

# %%
alist.append("hello")
alist.append(True)

# %%
alist
# Out:
# [10, 20, 30, 10, 'hello', True]

# %%
alist[2] = "world"

# %%
alist
# Out:
# [10, 20, 'world', 10, 'hello', True]

# %%
t = (1, 2, 3)

# %%
t
# Out:
# (1, 2, 3)

# %%
person = {
    "name": "Khuzzaim",
    "age": 25
}

# %%
person["name"]
# Out:
# 'Khuzzaim'

# %%
planet_gravity = {
    "Earth": 9.81,
    "Moon": 1.62,
    "Mars": 3.71
}

# %%
planet_gravity["Mars"]
# Out:
# 3.71

# %%
for x in [1,2,3]:
    print(x)
# Out:
# 1
# 2
# 3
