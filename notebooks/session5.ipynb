# %% [markdown]
# # Session 5: Python Modules and Pandas

# %%
## Loading and Exploring Data

# %%
import pandas
# %pwd
# %cd mukh11
# Out:
# /home/mukh11/mukh11

# %%
station_ids = pandas.read_csv("data/Niederschlag_1981-2010_Stationsliste.txt", encoding="iso-8859-1", delimiter=" *; *", engine="python")

# %%
station_ids
# Out:
#       Stations_id             Stationsname  geogr. Breite  geogr. Laenge  \
# 0               1                     Aach      47.841299       8.849299
# 1               2      Aachen (Kläranlage)      50.806581       6.099638
# 2               3                   Aachen      50.782659       6.094087
# 3               4             Aachen-Brand      50.768313       6.120705
# 4               6       Aalen-Unterrombach      48.836072      10.059764
# ...           ...                      ...            ...            ...
# 5735        19697  Wassertrüdingen/Wörnitz      49.046341      10.602684
# 5736        19698           Werda/Vogtland      50.448020      12.305168
# 5737        19701          Wertingen/Zusam      48.557500      10.674167
# 5738        19706      Oberndorf am Neckar      48.285077       8.576395
# 5739        19781               Ingolstadt      48.742909      11.423324
#
#       Stationshoehe           Bundesland  Unnamed: 6
# 0             478.0    Baden-Württemberg         NaN
# 1             138.0  Nordrhein-Westfalen         NaN
# 2             202.0  Nordrhein-Westfalen         NaN
# 3             243.0  Nordrhein-Westfalen         NaN
# 4             455.0    Baden-Württemberg         NaN
# ...             ...                  ...         ...
# 5735          435.0               Bayern         NaN
# 5736          595.0              Sachsen         NaN
# 5737          430.0               Bayern         NaN
# 5738          516.0    Baden-Württemberg         NaN
# 5739          367.0               Bayern         NaN
#
# [5740 rows x 7 columns]

# %%
station_ids.columns
# Out:
# Index(['Stations_id', 'Stationsname', 'geogr. Breite', 'geogr. Laenge',
#        'Stationshoehe', 'Bundesland', 'Unnamed: 6'],
#       dtype='str')

# %%
station_ids.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5740 entries, 0 to 5739
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Stations_id    5740 non-null   int64
#  1   Stationsname   5740 non-null   str
#  2   geogr. Breite  5740 non-null   float64
#  3   geogr. Laenge  5740 non-null   float64
#  4   Stationshoehe  5740 non-null   float64
#  5   Bundesland     5740 non-null   str
#  6   Unnamed: 6     0 non-null      float64
# dtypes: float64(4), int64(1), str(2)
# memory usage: 314.0 KB

# %%
station_ids.head()
# Out:
#    Stations_id         Stationsname  geogr. Breite  geogr. Laenge  \
# 0            1                 Aach      47.841299       8.849299
# 1            2  Aachen (Kläranlage)      50.806581       6.099638
# 2            3               Aachen      50.782659       6.094087
# 3            4         Aachen-Brand      50.768313       6.120705
# 4            6   Aalen-Unterrombach      48.836072      10.059764
#
#    Stationshoehe           Bundesland  Unnamed: 6
# 0          478.0    Baden-Württemberg         NaN
# 1          138.0  Nordrhein-Westfalen         NaN
# 2          202.0  Nordrhein-Westfalen         NaN
# 3          243.0  Nordrhein-Westfalen         NaN
# 4          455.0    Baden-Württemberg         NaN

# %%
station_ids.tail()
# Out:
#       Stations_id             Stationsname  geogr. Breite  geogr. Laenge  \
# 5735        19697  Wassertrüdingen/Wörnitz      49.046341      10.602684
# 5736        19698           Werda/Vogtland      50.448020      12.305168
# 5737        19701          Wertingen/Zusam      48.557500      10.674167
# 5738        19706      Oberndorf am Neckar      48.285077       8.576395
# 5739        19781               Ingolstadt      48.742909      11.423324
#
#       Stationshoehe         Bundesland  Unnamed: 6
# 5735          435.0             Bayern         NaN
# 5736          595.0            Sachsen         NaN
# 5737          430.0             Bayern         NaN
# 5738          516.0  Baden-Württemberg         NaN
# 5739          367.0             Bayern         NaN

# %%
station_ids.columns
# Out:
# Index(['Stations_id', 'Stationsname', 'geogr. Breite', 'geogr. Laenge',
#        'Stationshoehe', 'Bundesland', 'Unnamed: 6'],
#       dtype='str')

# %%
station_ids.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5740 entries, 0 to 5739
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Stations_id    5740 non-null   int64
#  1   Stationsname   5740 non-null   str
#  2   geogr. Breite  5740 non-null   float64
#  3   geogr. Laenge  5740 non-null   float64
#  4   Stationshoehe  5740 non-null   float64
#  5   Bundesland     5740 non-null   str
#  6   Unnamed: 6     0 non-null      float64
# dtypes: float64(4), int64(1), str(2)
# memory usage: 314.0 KB

# %%
station_ids.head()
# Out:
#    Stations_id         Stationsname  geogr. Breite  geogr. Laenge  \
# 0            1                 Aach      47.841299       8.849299
# 1            2  Aachen (Kläranlage)      50.806581       6.099638
# 2            3               Aachen      50.782659       6.094087
# 3            4         Aachen-Brand      50.768313       6.120705
# 4            6   Aalen-Unterrombach      48.836072      10.059764
#
#    Stationshoehe           Bundesland  Unnamed: 6
# 0          478.0    Baden-Württemberg         NaN
# 1          138.0  Nordrhein-Westfalen         NaN
# 2          202.0  Nordrhein-Westfalen         NaN
# 3          243.0  Nordrhein-Westfalen         NaN
# 4          455.0    Baden-Württemberg         NaN

# %%
station_ids.columns
# Out:
# Index(['Stations_id', 'Stationsname', 'geogr. Breite', 'geogr. Laenge',
#        'Stationshoehe', 'Bundesland', 'Unnamed: 6'],
#       dtype='str')

# %%
station_ids.drop(columns=["Unnamed: 6"], inplace=True)

# %%
station_ids = station_ids.set_index("Stations_id")

# %%
station_ids.columns
# Out:
# Index(['Stationsname', 'geogr. Breite', 'geogr. Laenge', 'Stationshoehe',
#        'Bundesland'],
#       dtype='str')

# %%
station_ids["Bundesland"]
# Out:
# Stations_id
# 1          Baden-Württemberg
# 2        Nordrhein-Westfalen
# 3        Nordrhein-Westfalen
# 4        Nordrhein-Westfalen
# 6          Baden-Württemberg
#                 ...
# 19697                 Bayern
# 19698                Sachsen
# 19701                 Bayern
# 19706      Baden-Württemberg
# 19781                 Bayern
# Name: Bundesland, Length: 5740, dtype: str

# %%
station_ids.groupby("Bundesland").count().sort_values("Stationsname", ascending=False)
# Out:
#                         Stationsname  geogr. Breite  geogr. Laenge  \
# Bundesland
# Bayern                          1337           1337           1337
# Baden-Württemberg                619            619            619
# Niedersachsen                    611            611            611
# Hessen                           436            436            436
# Nordrhein-Westfalen              436            436            436
# Sachsen-Anhalt                   411            411            411
# Thüringen                        391            391            391
# Sachsen                          356            356            356
# Brandenburg                      302            302            302
# Rheinland-Pfalz                  264            264            264
# Mecklenburg-Vorpommern           237            237            237
# Schleswig-Holstein               223            223            223
# Saarland                          54             54             54
# Berlin                            29             29             29
# Hamburg                           19             19             19
# Bremen                            15             15             15
#
#                         Stationshoehe
# Bundesland
# Bayern                           1337
# Baden-Württemberg                 619
# Niedersachsen                     611
# Hessen                            436
# Nordrhein-Westfalen               436
# Sachsen-Anhalt                    411
# Thüringen                         391
# Sachsen                           356
# Brandenburg                       302
# Rheinland-Pfalz                   264
# Mecklenburg-Vorpommern            237
# Schleswig-Holstein                223
# Saarland                           54
# Berlin                             29
# Hamburg                            19
# Bremen                             15

# %%
mask = station_ids.Bundesland == "Bayern"

# %%
mask
# Out:
# Stations_id
# 1        False
# 2        False
# 3        False
# 4        False
# 6        False
#          ...
# 19697     True
# 19698    False
# 19701     True
# 19706    False
# 19781     True
# Name: Bundesland, Length: 5740, dtype: bool

# %%
station_ids[mask]
# Out:
#                             Stationsname  geogr. Breite  geogr. Laenge  \
# Stations_id
# 10                   Abbach,Bad-Dünzling      48.885697      12.107925
# 15                              Abenberg      49.234641      10.966676
# 16               Abenberg-Wassermungenau      49.219251      10.884495
# 17               Abensberg-Sandharlanden      48.842100      11.819366
# 24                               Achthal      47.833300      12.783300
# ...                                  ...            ...            ...
# 19694              Tittmoning/Oberbayern      48.066895      12.763446
# 19695        Untergriesbach/Niederbayern      48.599508      13.646542
# 19697            Wassertrüdingen/Wörnitz      49.046341      10.602684
# 19701                    Wertingen/Zusam      48.557500      10.674167
# 19781                         Ingolstadt      48.742909      11.423324
#
#              Stationshoehe Bundesland
# Stations_id
# 10                   378.0     Bayern
# 15                   391.5     Bayern
# 16                   370.0     Bayern
# 17                   380.0     Bayern
# 24                   582.0     Bayern
# ...                    ...        ...
# 19694                382.0     Bayern
# 19695                495.0     Bayern
# 19697                435.0     Bayern
# 19701                430.0     Bayern
# 19781                367.0     Bayern
#
# [1337 rows x 5 columns]

# %%
bayern = station_ids[mask]

# %%
station_ids.Bundesland.iloc[-1]
# Out:
# 'Bayern'

# %%
bayern.loc[17]
# Out:
# Stationsname     Abensberg-Sandharlanden
# geogr. Breite                    48.8421
# geogr. Laenge                  11.819366
# Stationshoehe                      380.0
# Bundesland                        Bayern
# Name: 17, dtype: object

# %%
mask = station_ids.Bundesland == "Berlin"

# %%
berlin = station_ids[mask]
berlin
# Out:
#                           Stationsname  geogr. Breite  geogr. Laenge  \
# Stations_id
# 394                 Berlin (Rosenthal)      52.590285      13.383258
# 399              Berlin-Alexanderplatz      52.519785      13.405678
# 400                        Berlin-Buch      52.630956      13.502135
# 401              Berlin-Charlottenburg      52.516700      13.266700
# 402               Berlin-Dahlem (LFAG)      52.456399      13.299675
# 403                 Berlin-Dahlem (FU)      52.453711      13.301731
# 404             Berlin-Friedrichsfelde      52.504696      13.521539
# 406              Berlin-Friedrichshain      52.516700      13.416700
# 407                     Berlin-Frohnau      52.646077      13.285772
# 409                Berlin-Johannisthal      52.450000      13.500000
# 410                   Berlin-Kaniswall      52.404034      13.730854
# 412                  Berlin-Karlshorst      52.483300      13.516700
# 413                   Berlin-Kaulsdorf      52.504396      13.579930
# 414                    Berlin-Köpenick      52.475300      13.589930
# 416                 Berlin-Lichtenrade      52.406906      13.412659
# 417          Berlin-Lichterfelde (Süd)      52.414404      13.303575
# 418            Berlin-Lichterfelde Ost      52.408905      13.331571
# 419                     Berlin-Malchow      52.575287      13.483243
# 420                     Berlin-Marzahn      52.544744      13.559789
# 421                Berlin-Marzahn, Apw      52.533300      13.550000
# 422                       Berlin-Mitte      52.533300      13.383300
# 425                       Berlin-Rudow      52.404407      13.483848
# 426                 Berlin-Schmöckwitz      52.382302      13.623638
# 429                     Berlin-Spandau      52.566685      13.169392
# 430                       Berlin-Tegel      52.564402      13.308805
# 432           Berlin-Tegeler Fliesstal      52.604382      13.295172
# 433                   Berlin-Tempelhof      52.467451      13.402120
# 434                     Berlin-Treptow      52.455301      13.469949
# 435                  Berlin-Zehlendorf      52.428902      13.232686
#
#              Stationshoehe Bundesland
# Stations_id
# 394                   43.0     Berlin
# 399                   35.8     Berlin
# 400                   60.0     Berlin
# 401                   55.0     Berlin
# 402                   55.0     Berlin
# 403                   51.0     Berlin
# 404                   38.0     Berlin
# 406                   33.0     Berlin
# 407                   48.0     Berlin
# 409                   35.0     Berlin
# 410                   33.0     Berlin
# 412                   35.0     Berlin
# 413                   39.0     Berlin
# 414                   36.0     Berlin
# 416                   47.0     Berlin
# 417                   43.0     Berlin
# 418                   45.0     Berlin
# 419                   53.0     Berlin
# 420                   61.0     Berlin
# 421                   52.0     Berlin
# 422                   35.0     Berlin
# 425                   38.0     Berlin
# 426                   36.0     Berlin
# 429                   32.0     Berlin
# 430                   35.5     Berlin
# 432                   36.0     Berlin
# 433                   47.7     Berlin
# 434                   35.0     Berlin
# 435                   45.0     Berlin

# %%
berlin["Stationsname"]
# Out:
# Stations_id
# 394           Berlin (Rosenthal)
# 399        Berlin-Alexanderplatz
# 400                  Berlin-Buch
# 401        Berlin-Charlottenburg
# 402         Berlin-Dahlem (LFAG)
# 403           Berlin-Dahlem (FU)
# 404       Berlin-Friedrichsfelde
# 406        Berlin-Friedrichshain
# 407               Berlin-Frohnau
# 409          Berlin-Johannisthal
# 410             Berlin-Kaniswall
# 412            Berlin-Karlshorst
# 413             Berlin-Kaulsdorf
# 414              Berlin-Köpenick
# 416           Berlin-Lichtenrade
# 417    Berlin-Lichterfelde (Süd)
# 418      Berlin-Lichterfelde Ost
# 419               Berlin-Malchow
# 420               Berlin-Marzahn
# 421          Berlin-Marzahn, Apw
# 422                 Berlin-Mitte
# 425                 Berlin-Rudow
# 426           Berlin-Schmöckwitz
# 429               Berlin-Spandau
# 430                 Berlin-Tegel
# 432     Berlin-Tegeler Fliesstal
# 433             Berlin-Tempelhof
# 434               Berlin-Treptow
# 435            Berlin-Zehlendorf
# Name: Stationsname, dtype: str

# %%
berlin[berlin["Stationsname"].str.contains("Alexander")]
# Out:
#                       Stationsname  geogr. Breite  geogr. Laenge  \
# Stations_id
# 399          Berlin-Alexanderplatz      52.519785      13.405678
#
#              Stationshoehe Bundesland
# Stations_id
# 399                   35.8     Berlin

# %%
precip = pandas.read_csv(
    "data/produkt_precipitation_399_akt.txt",
    delimiter=" *; *",
    engine="python"
)

# %%
precip.head()
precip.columns
# Out:
# Index(['STATIONS_ID', 'MESS_DATUM', 'QUALITAETS_NIVEAU', 'STRUKTUR_VERSION',
#        'NIEDERSCHLAGSHOEHE', 'eor'],
#       dtype='str')

# %%
precip.MESS_DATUM = pandas.to_datetime(
    precip.MESS_DATUM,
    format="%Y%m%d%H"
)

# %%
precip = precip[["MESS_DATUM", "NIEDERSCHLAGSHOEHE"]]

precip = precip.rename(columns={
    "MESS_DATUM": "date",
    "NIEDERSCHLAGSHOEHE": "precipitation"
})

precip = precip.set_index("date")

# %%
monthly = precip.resample("ME").sum()

# %%
monthly.head()
monthly.describe()
# Out:
#        precipitation
# count     129.000000
# mean       39.528372
# std        28.812164
# min         0.000000
# 25%        22.910000
# 50%        33.640000
# 75%        48.600000
# max       166.300000

# %%
precip_ref = pandas.read_csv(
    "data/Niederschlag_1981-2010.txt",
    delimiter=" *; *",
    encoding="iso-8859-1",
    engine="python",
    decimal=","
)

# %%
berlin[berlin["Stationsname"].str.contains("Alexander", case=False)]
# Out:
#                       Stationsname  geogr. Breite  geogr. Laenge  \
# Stations_id
# 399          Berlin-Alexanderplatz      52.519785      13.405678
#
#              Stationshoehe Bundesland
# Stations_id
# 399                   35.8     Berlin

# %%
station_id = 399

# %%
precip_ref.head()
# Out:
#    Stations_id Bezugszeitraum  Datenquelle  Jan.  Feb.  März  Apr.   Mai  \
# 0            1      1981-2010           46  48.4  45.6  49.7  51.5  88.7
# 1            2      1981-2010           45  74.3  66.0  64.4  58.2  70.9
# 2            3      1981-2010           45  68.1  63.6  67.0  55.7  72.0
# 3            4      1981-2010           46  68.9  66.1  67.4  55.9  71.5
# 4            6      1981-2010           45  66.2  65.3  75.2  55.8  93.0
#
#    Jun.  Jul.  Aug.  Sept.  Okt.  Nov.  Dez.   Jahr  Unnamed: 16
# 0  93.0  95.7  85.1   62.5  61.3  55.5  60.1  797.1          NaN
# 1  79.8  71.4  69.5   69.7  68.4  64.6  78.4  838.6          NaN
# 2  80.3  75.2  74.8   69.2  70.0  66.1  75.5  837.4          NaN
# 3  81.2  75.2  73.2   68.8  69.3  65.2  76.5  839.2          NaN
# 4  83.0  95.8  79.2   69.8  67.3  67.7  80.2  898.4          NaN

# %%
precip_ref.columns
# Out:
# Index(['Stations_id', 'Bezugszeitraum', 'Datenquelle', 'Jan.', 'Feb.', 'März',
#        'Apr.', 'Mai', 'Jun.', 'Jul.', 'Aug.', 'Sept.', 'Okt.', 'Nov.', 'Dez.',
#        'Jahr', 'Unnamed: 16'],
#       dtype='str')

# %%
precip_ref.loc[station_id]
# Out:
# Stations_id             462
# Bezugszeitraum    1981-2010
# Datenquelle              45
# Jan.                   90.7
# Feb.                   68.5
# März                   79.5
# Apr.                   52.2
# Mai                    64.1
# Jun.                   95.4
# Jul.                   96.7
# Aug.                   89.8
# Sept.                  97.9
# Okt.                  105.9
# Nov.                   92.7
# Dez.                   98.0
# Jahr                 1031.2
# Unnamed: 16             NaN
# Name: 399, dtype: object

# %%
precip_ref
# Out:
#       Stations_id Bezugszeitraum  Datenquelle  Jan.  Feb.  März  Apr.    Mai  \
# 0               1      1981-2010           46  48.4  45.6  49.7  51.5   88.7
# 1               2      1981-2010           45  74.3  66.0  64.4  58.2   70.9
# 2               3      1981-2010           45  68.1  63.6  67.0  55.7   72.0
# 3               4      1981-2010           46  68.9  66.1  67.4  55.9   71.5
# 4               6      1981-2010           45  66.2  65.3  75.2  55.8   93.0
# ...           ...            ...          ...   ...   ...   ...   ...    ...
# 5704        19697      1981-2010           45  54.4  48.5  56.9  42.7   73.6
# 5705        19698      1981-2010           45  59.0  54.4  63.9  57.0   75.8
# 5706        19701      1981-2010           45  46.1  39.8  54.0  52.0   84.1
# 5707        19706      1981-2010           45  89.0  82.0  82.3  69.9  102.4
# 5708        19781      1981-2010           45  47.6  40.1  47.6  42.0   75.1
#
#       Jun.   Jul.  Aug.  Sept.  Okt.  Nov.  Dez.    Jahr  Unnamed: 16
# 0     93.0   95.7  85.1   62.5  61.3  55.5  60.1   797.1          NaN
# 1     79.8   71.4  69.5   69.7  68.4  64.6  78.4   838.6          NaN
# 2     80.3   75.2  74.8   69.2  70.0  66.1  75.5   837.4          NaN
# 3     81.2   75.2  73.2   68.8  69.3  65.2  76.5   839.2          NaN
# 4     83.0   95.8  79.2   69.8  67.3  67.7  80.2   898.4          NaN
# ...    ...    ...   ...    ...   ...   ...   ...     ...          ...
# 5704  76.4   90.3  73.7   55.5  58.7  55.1  64.5   753.7          NaN
# 5705  86.0  102.7  82.8   71.2  65.2  69.9  68.3   856.1          NaN
# 5706  85.8  101.3  78.8   66.5  58.4  56.0  61.4   787.5          NaN
# 5707  84.0   90.3  73.0   69.8  78.9  84.6  96.7  1012.1          NaN
# 5708  77.9   85.9  76.4   59.0  53.8  51.5  58.5   711.6          NaN
#
# [5709 rows x 17 columns]

# %%
precip_ref.drop(precip_ref.columns[-1],axis=1, inplace=True)

# %%
precip_ref
# Out:
#       Stations_id Bezugszeitraum  Datenquelle  Jan.  Feb.  März  Apr.    Mai  \
# 0               1      1981-2010           46  48.4  45.6  49.7  51.5   88.7
# 1               2      1981-2010           45  74.3  66.0  64.4  58.2   70.9
# 2               3      1981-2010           45  68.1  63.6  67.0  55.7   72.0
# 3               4      1981-2010           46  68.9  66.1  67.4  55.9   71.5
# 4               6      1981-2010           45  66.2  65.3  75.2  55.8   93.0
# ...           ...            ...          ...   ...   ...   ...   ...    ...
# 5704        19697      1981-2010           45  54.4  48.5  56.9  42.7   73.6
# 5705        19698      1981-2010           45  59.0  54.4  63.9  57.0   75.8
# 5706        19701      1981-2010           45  46.1  39.8  54.0  52.0   84.1
# 5707        19706      1981-2010           45  89.0  82.0  82.3  69.9  102.4
# 5708        19781      1981-2010           45  47.6  40.1  47.6  42.0   75.1
#
#       Jun.   Jul.  Aug.  Sept.  Okt.  Nov.  Dez.    Jahr
# 0     93.0   95.7  85.1   62.5  61.3  55.5  60.1   797.1
# 1     79.8   71.4  69.5   69.7  68.4  64.6  78.4   838.6
# 2     80.3   75.2  74.8   69.2  70.0  66.1  75.5   837.4
# 3     81.2   75.2  73.2   68.8  69.3  65.2  76.5   839.2
# 4     83.0   95.8  79.2   69.8  67.3  67.7  80.2   898.4
# ...    ...    ...   ...    ...   ...   ...   ...     ...
# 5704  76.4   90.3  73.7   55.5  58.7  55.1  64.5   753.7
# 5705  86.0  102.7  82.8   71.2  65.2  69.9  68.3   856.1
# 5706  85.8  101.3  78.8   66.5  58.4  56.0  61.4   787.5
# 5707  84.0   90.3  73.0   69.8  78.9  84.6  96.7  1012.1
# 5708  77.9   85.9  76.4   59.0  53.8  51.5  58.5   711.6
#
# [5709 rows x 16 columns]

# %%
precip_ref=precip_ref.loc[:, "Jan.":"Dez."]

# %%
precip_ref.loc[station_id].plot.bar()
# Out:
# <Axes: >

# %%
precip = pandas.read_csv(
    "data/produkt_precipitation_399_akt.txt",
    delimiter=" *; *",
    engine="python"
)

# %%
precip.head()
precip.columns
# Out:
# Index(['STATIONS_ID', 'MESS_DATUM', 'QUALITAETS_NIVEAU', 'STRUKTUR_VERSION',
#        'NIEDERSCHLAGSHOEHE', 'eor'],
#       dtype='str')

# %%
precip["MESS_DATUM"] = pandas.to_datetime(
    precip["MESS_DATUM"],
    format="%Y%m%d%H"
)

# %%
precip.head()
# Out:
#    STATIONS_ID          MESS_DATUM  QUALITAETS_NIVEAU  STRUKTUR_VERSION  \
# 0          399 2015-08-20 01:00:00                  3                 0
# 1          399 2015-08-20 02:00:00                  3                 0
# 2          399 2015-08-20 03:00:00                  3                 0
# 3          399 2015-08-20 04:00:00                  3                 0
# 4          399 2015-08-20 05:00:00                  3                 0
#
#    NIEDERSCHLAGSHOEHE  eor
# 0                 0.0  eor
# 1                 0.0  eor
# 2                 0.0  eor
# 3                 0.0  eor
# 4                 0.0  eor

# %%
precip = precip[["MESS_DATUM", "NIEDERSCHLAGSHOEHE"]]

# %%
precip = precip.rename(columns={
    "MESS_DATUM": "date",
    "NIEDERSCHLAGSHOEHE": "precipitation"
})

# %%
precip = precip.set_index("date")

# %%
monthly = precip.resample("ME").sum()

# %%
monthly.head()
# Out:
#             precipitation
# date
# 2015-08-31          18.90
# 2015-09-30          29.19
# 2015-10-31          60.91
# 2015-11-30          58.59
# 2015-12-31          27.34

# %%
refs = pandas.DataFrame(
    {"precipitation": precip_ref.loc[station_id].to_list() * 11},
    index=pandas.date_range("2015-01-01", "2025-12-31", freq="ME")
)

# %%
monthly["climate"] = refs

# %%
monthly["anomaly"] = monthly["precipitation"] - monthly["climate"]

# %%
monthly[["precipitation", "climate"]].plot()
# Out:
# <Axes: xlabel='date'>

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,6))

monthly[["precipitation", "climate"]].plot(ax=ax)

ax.set_title("Precipitation Berlin (Alexanderplatz)")
# Out:
# Text(0.5, 1.0, 'Precipitation Berlin (Alexanderplatz)')

# %%
monthly["anomaly"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(3, 1, figsize=(12,10))

# Actual vs Climate
monthly[["precipitation", "climate"]].plot(ax=axs[0])
axs[0].set_title("Actual vs Climate Precipitation")
axs[0].set_ylabel("mm")

# Anomaly line plot
monthly["anomaly"].plot(ax=axs[1])
axs[1].set_title("Precipitation Anomaly")
axs[1].set_ylabel("mm")

# Anomaly bar plot 
monthly["anomaly"].plot(kind="bar", ax=axs[2])

for i, label in enumerate(axs[2].get_xticklabels()):
    if i % 12 != 0:
        label.set_visible(False)

axs[2].set_title("Anomaly Bar Plot")
axs[2].set_ylabel("mm")

# show only yearly labels
ax.set_xticks(range(0, len(monthly), 12))
ax.set_xticklabels(monthly.index.strftime("%Y")[::12], rotation=45)

axs[2].set_title("Anomaly Bar Plot")
axs[2].set_ylabel("mm")

plt.tight_layout()
